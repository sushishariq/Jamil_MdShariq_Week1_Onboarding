# %% [markdown]
# # Setup test
# Libraries downloaded, imported and system verified. Environment is fine.

# %%
# !pip install simpy numpy pandas matplotlib scipy pulp pymoo scikit-learn

# %%
#libraries importing
import simpy, numpy, pandas, matplotlib, scipy, pulp, pymoo, sklearn
print("All required packages imported successfully.")
# Out:
# All required packages imported successfully.

# %%
#system check
import sys
print(sys.version)
# Out:
# 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:16:10) [GCC 11.2.0]
